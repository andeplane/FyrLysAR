# %%
import json
import time
import pdfplumber
from pdfplumber.pdf import Page as PDFPlumberPage
from pdfplumber.utils.text import WordExtractor, objects_to_bbox
from dataclasses import dataclass, asdict, field
SCALING_FACTOR = 2.77793494

# %%
def merge_text_elements(text_elements, max_x_distance=10/SCALING_FACTOR, max_y_distance=5/SCALING_FACTOR):
    """
    Merges text elements that are horizontally close and vertically aligned based on bounding box sides.

    Args:
        text_elements (list): List of text elements with 'description' and 'bounding_box'.
        max_x_distance (int): Maximum horizontal distance in pixels to consider for merging.
        max_y_distance (int): Maximum vertical distance in pixels to consider for merging.

    Returns:
        list: A new list of merged text elements.
    """
    if not text_elements:
        return []

    # Sort text elements by top-left y-coordinate, then by left x-coordinate
    sorted_elements = sorted(text_elements, key=lambda el: (el['bounding_box'][0][1], el['bounding_box'][0][0]))
    elements_to_keep = []
    while True:
        merged = False
        merged_elements = []
        current_element = sorted_elements[0].copy()
        
        for next_element in sorted_elements[1:]:
            #print("Considering merging ", current_element['description'], " and ", next_element['description'])
            #print("  y coordinates: ", [coord[1] for coord in current_element['bounding_box']], " and ", [coord[1] for coord in next_element['bounding_box']])
            # Extract bounding box coordinates
            current_bbox = current_element['bounding_box']
            next_bbox = next_element['bounding_box']

            # Determine right side of current and left side of next
            current_right_x = max([coord[0] for coord in current_bbox])
            current_left_x = min([coord[0] for coord in current_bbox])
            next_left_x = min([coord[0] for coord in next_bbox])
            next_right_x = max([coord[0] for coord in next_bbox])

            # Calculate horizontal distance between right of current and left of next
            horizontal_distance1 = next_left_x - current_right_x
            horizontal_distance2 = current_left_x - next_right_x

            # Extract top y-coordinates for vertical alignment
            current_top_y = current_bbox[0][1]
            next_top_y = next_bbox[0][1]
            vertical_distance = abs(next_top_y - current_top_y)
            # print("  Vertical distance: ", vertical_distance)
            # print("  Horizontal distance1: ", horizontal_distance1)
            # print("  Horizontal distance2: ", horizontal_distance2)
            # Decide whether to merge
            if (abs(horizontal_distance1) < max_x_distance or abs(horizontal_distance2) < max_x_distance) and abs(vertical_distance) <= max_y_distance:
                # Merge descriptions
                # Decide which is left and which is right
                if current_right_x < next_left_x:
                    current_element['description'] += ' ' +  next_element['description']
                else:
                    current_element['description'] = next_element['description'] + ' ' + current_element['description']
                # Merge bounding boxes
                # New left_x is min of current and next
                new_left_x = min([coord[0] for coord in current_bbox] + [coord[0] for coord in next_bbox])
                # New right_x is max of current and next
                new_right_x = max([coord[0] for coord in current_bbox] + [coord[0] for coord in next_bbox])
                # New top_y is min of current and next
                new_top_y = min([coord[1] for coord in current_bbox] + [coord[1] for coord in next_bbox])
                # New bottom_y is max of current and next
                new_bottom_y = max([coord[1] for coord in current_bbox] + [coord[1] for coord in next_bbox])

                # Define new bounding box
                new_bounding_box = [
                    (new_left_x, new_top_y),
                    (new_right_x, new_top_y),
                    (new_right_x, new_bottom_y),
                    (new_left_x, new_bottom_y)
                ]
                # print("  Merged them!")
                current_element['bounding_box'] = new_bounding_box
                merged = True
            else:
                # No merge; add the current element to the list
                merged_elements.append(next_element)

        # Add the last element
        # merged_elements.append(current_element)
        
        # Update sorted_elements for next iteration
        sorted_elements = merged_elements.copy()
        # if merged:
        #     merged_elements.insert(0, current_element)
        elements_to_keep.append(current_element)
        
        # print("Nothing else to merge. Keeping ", current_element)
        # elements_to_keep.append(current_element)
        if len(sorted_elements) == 0:
            # Finished with all elements
            break
        else:
            current_element = merged_elements[0]
                
    return elements_to_keep

def find_text(target_text, text_elements):
    """
    Finds the first occurrence of the target text in the list of text elements.

    Args:
        target_text (str): The text to search for.
        text_elements (list): List of text elements with 'description' and 'bounding_box'.

    Returns:
        dict or None: The text element containing the target text or None if not found.
    """
    target_lower = target_text.strip().lower().replace(',', '').replace(' ', '').replace('.', '')
    for element in text_elements:
        if element['description'].strip().lower().replace(',', '').replace(' ', '').replace('.', '') == target_lower:
            return element
    return None

def find_element_containing_point(x, y, text_elements):
    """
    Finds all text elements whose bounding boxes contain the given (x, y) point.

    Args:
        x (int): The x-coordinate of the point.
        y (int): The y-coordinate of the point.
        text_elements (list): List of text elements with 'description' and 'bounding_box'.

    Returns:
        list: A list of text elements containing the point.
    """
    containing_elements = []
    for element in text_elements:
        bbox = element['bounding_box']
        # Extract x and y coordinates separately
        x_coords = [coord[0] for coord in bbox]
        y_coords = [coord[1] for coord in bbox]
        min_x, max_x = min(x_coords), max(x_coords)
        min_y, max_y = min(y_coords), max(y_coords)

        if min_x <= x <= max_x and min_y <= y <= max_y:
            containing_elements.append(element)
    if len(containing_elements) > 1:
        print(f"WARNING! Found {len(containing_elements)} elements containing point {x}, {y}")
    return containing_elements[0] if len(containing_elements) > 0 else None

def find_text_element_containing_point(x, y, text_elements):
    element = find_element_containing_point(x, y, text_elements)
    return element['description'] if element else None

def extract_text_elements(pdf_page):
    elements = []

    lines = pdf_page.extract_text_lines(layout=True, x_density=3)
    # print("lines", lines)
    annotations_by_lines = {}
    for idx, line in enumerate(lines):
        # print("line", line)
        
        wordPointer = 0  # noqa: N806
        chars = line["chars"]
        annotations = []
        for word in line["text"].split():
            # print("  word", word)
            ordered_chars = chars[wordPointer : wordPointer + len(word)]
            wordPointer += len(word)  # noqa: N806

            x0, y0, x1, y1 = objects_to_bbox(ordered_chars)
            elements.append({
                'description': word,
                'bounding_box': [(x0, y0), (x1, y0), (x1, y1), (x0, y1)]
            })
            # print("  ", ordered_chars, x0, y0, x1, y1)
    return elements
    
def perform_text_extraction(pdf_page):
    texts_with_bounding_box = extract_text_elements(pdf_page)
    
    # Merge text elements based on proximity
    merged_texts = merge_text_elements(texts_with_bounding_box, max_x_distance=10/SCALING_FACTOR, max_y_distance=5/SCALING_FACTOR)
    return merged_texts

# %%
def parse_lighthouses(text_elements):
    global total_number_of_lighthouses
    @dataclass
    class Lighthouse:
        fyrnr: str
        bounding_box: list[tuple[int, int]]
        name: str | None = None
        latitude: str | None = None
        longitude: str | None = None
        height_over_sea_level: str | None = None
        lysvidde_r: str | None = None
        lysvidde_g: str | None = None
        lysvidde_w: str | None = None
        sector_colors: list[dict] = field(default_factory=list)
        
    lighthouses_on_page = {}
    fyrnr_with_bounding_boxes = []
    # Find Fyrnr. elements. y coordinates start at 180 and increase by 10 for each line 
    for y in range(int(180/SCALING_FACTOR), int(1550/SCALING_FACTOR), int(10/SCALING_FACTOR)):
        FYRNR_X_COORDINATE = 163/SCALING_FACTOR
        element = find_element_containing_point(FYRNR_X_COORDINATE, y, text_elements)
        if element:
            fyrnr = element['description']
            if not fyrnr in lighthouses_on_page:
                lighthouses_on_page[fyrnr] = True # Found it
                fyrnr_with_bounding_boxes.append({
                    'fyrnr': fyrnr,
                    'bounding_box': element['bounding_box']
                })
    # Compute the full bounding box for each lighthouse
    for index, fyrnr_with_bounding_box in enumerate(fyrnr_with_bounding_boxes):
        DELTA_Y_FROM_TOP_OF_NEXT_BOX_TO_BOTTOM_OF_THIS_LIGHTHOUSE = 11/SCALING_FACTOR
        Y_FOR_LAST_LIGHTHOUSE = 1590/SCALING_FACTOR
        X_MAX_FOR_LIGHTHOUSE_BOUNDING_BOX = 2250/SCALING_FACTOR
        if index < len(fyrnr_with_bounding_boxes) - 1:
            next_fyrnr_with_bounding_box = fyrnr_with_bounding_boxes[index + 1]
            fyrnr = fyrnr_with_bounding_box['fyrnr']
            bounding_box = fyrnr_with_bounding_box['bounding_box']
            next_bounding_box = next_fyrnr_with_bounding_box['bounding_box']
            full_bounding_box = [bounding_box[0], (X_MAX_FOR_LIGHTHOUSE_BOUNDING_BOX, next_bounding_box[0][1] - DELTA_Y_FROM_TOP_OF_NEXT_BOX_TO_BOTTOM_OF_THIS_LIGHTHOUSE)]
        else:
            # This is the last lighthouse
            fyrnr = fyrnr_with_bounding_box['fyrnr']
            bounding_box = fyrnr_with_bounding_box['bounding_box']
            full_bounding_box = [bounding_box[0], (X_MAX_FOR_LIGHTHOUSE_BOUNDING_BOX, Y_FOR_LAST_LIGHTHOUSE)]
        
        lighthouses_on_page[fyrnr] = Lighthouse(fyrnr, full_bounding_box)
    for fyrnr, lighthouse in lighthouses_on_page.items():
        total_number_of_lighthouses += 1
        NAME_X_COORDINATE = 220/SCALING_FACTOR
        NAME_Y_COORDINATE = lighthouse.bounding_box[0][1] + 36/SCALING_FACTOR
        name = find_text_element_containing_point(NAME_X_COORDINATE, NAME_Y_COORDINATE, text_elements)
        lighthouses_on_page[fyrnr].name = name
        
        LATITUDE_X_COORDINATE = 650/SCALING_FACTOR
        LATITUDE_Y_COORDINATE = lighthouse.bounding_box[0][1] + 7/SCALING_FACTOR
        # 78 12.6340
        latitude = find_text_element_containing_point(LATITUDE_X_COORDINATE, LATITUDE_Y_COORDINATE, text_elements)
        # Convert to degrees
        latitude = float(latitude.split()[0]) + float(latitude.split()[1]) / 60
        
        LONGITUDE_X_COORDINATE = 650/SCALING_FACTOR
        LONGITUDE_Y_COORDINATE = lighthouse.bounding_box[0][1] + 32/SCALING_FACTOR
        
        longitude = find_text_element_containing_point(LONGITUDE_X_COORDINATE, LONGITUDE_Y_COORDINATE, text_elements)
        # Convert to degrees
        longitude = float(longitude.split()[0]) + float(longitude.split()[1]) / 60

        lighthouses_on_page[fyrnr].latitude = latitude
        lighthouses_on_page[fyrnr].longitude = longitude

        KARAKTER_X_COORDINATE = 800/SCALING_FACTOR
        KARAKTER_Y_COORDINATE = lighthouse.bounding_box[0][1] + 7/SCALING_FACTOR
        karakter = find_text_element_containing_point(KARAKTER_X_COORDINATE, KARAKTER_Y_COORDINATE, text_elements)
        lighthouses_on_page[fyrnr].karakter = karakter

        HEIGHT_OVER_SEA_LEVEL_X_COORDINATE = 940/SCALING_FACTOR
        HEIGHT_OVER_SEA_LEVEL_Y_COORDINATE = lighthouse.bounding_box[0][1] + 7/SCALING_FACTOR
        height_over_sea_level = find_text_element_containing_point(HEIGHT_OVER_SEA_LEVEL_X_COORDINATE, HEIGHT_OVER_SEA_LEVEL_Y_COORDINATE, text_elements)    
        lighthouses_on_page[fyrnr].height_over_sea_level = float(height_over_sea_level.replace(",", ".")) if height_over_sea_level else None

        LYSVIDDE_X_COORDINATE = 1338/SCALING_FACTOR
        LYSVIDDE_R_Y_COORDINATE = lighthouse.bounding_box[0][1] + 7/SCALING_FACTOR
        LYSVIDDE_G_Y_COORDINATE = lighthouse.bounding_box[0][1] + 32/SCALING_FACTOR
        LYSVIDDE_W_Y_COORDINATE = lighthouse.bounding_box[0][1] + 57/SCALING_FACTOR
        lysvidde_r = find_text_element_containing_point(LYSVIDDE_X_COORDINATE, LYSVIDDE_R_Y_COORDINATE, text_elements)
        lysvidde_g = find_text_element_containing_point(LYSVIDDE_X_COORDINATE, LYSVIDDE_G_Y_COORDINATE, text_elements)
        lysvidde_w = find_text_element_containing_point(LYSVIDDE_X_COORDINATE, LYSVIDDE_W_Y_COORDINATE, text_elements)
        lighthouses_on_page[fyrnr].lysvidde_r = float(lysvidde_r.replace(",", ".")) if lysvidde_r else None
        lighthouses_on_page[fyrnr].lysvidde_g = float(lysvidde_g.replace(",", ".")) if lysvidde_g else None
        lighthouses_on_page[fyrnr].lysvidde_w = float(lysvidde_w.replace(",", ".")) if lysvidde_w else None

        # Find sectors
        SECTOR_COLOR_X_COORDINATE = 1482/SCALING_FACTOR
        SECTOR_FIRST_COLOR_Y_COORDINATE = lighthouse.bounding_box[0][1] + 9/SCALING_FACTOR
        SECTOR_COLOR_LINE_HEIGHT = 5/SCALING_FACTOR
        current_y_coordinate = SECTOR_FIRST_COLOR_Y_COORDINATE
        current_color = None

        SINGLE_LINE_HEIGHT = 28/SCALING_FACTOR
        SECTOR_FIRST_ANGLE_X_COORDINATE = 1536/SCALING_FACTOR
        SECTOR_SECOND_ANGLE_X_COORDINATE = 1614/SCALING_FACTOR
        
        while current_y_coordinate < lighthouse.bounding_box[1][1]:
            sector_color = find_element_containing_point(SECTOR_COLOR_X_COORDINATE, current_y_coordinate, text_elements)
            if sector_color and sector_color['description'] != current_color:
                current_color = sector_color['description']
                if current_color in ['R', 'G', 'W']:
                    mean_y_coordinate = (sector_color['bounding_box'][0][1] + sector_color['bounding_box'][2][1]) / 2
                    sector_from = find_text_element_containing_point(SECTOR_FIRST_ANGLE_X_COORDINATE, mean_y_coordinate, text_elements)
                    sector_to = find_text_element_containing_point(SECTOR_SECOND_ANGLE_X_COORDINATE, mean_y_coordinate, text_elements)
                    sector_from_float = float(sector_from.replace(",", ".")) if sector_from else None
                    sector_to_float = float(sector_to.replace(",", ".").replace("-", "")) if sector_to else None
                    if sector_from_float is None:
                        print(f"WARNING! Sector from is None for {fyrnr} {sector_color['description']} {sector_from}. Choosing 0.0 instead.")
                        sector_from_float = 0.0
                    

                    lighthouses_on_page[fyrnr].sector_colors.append({
                        'color': sector_color['description'],
                        'from': sector_from_float,
                        'to': float(sector_to.replace(",", ".").replace("-", ""))
                    })
                
            current_y_coordinate += SECTOR_COLOR_LINE_HEIGHT
    
    def should_keep_lighthouse(lighthouse):
        if lighthouse.lysvidde_r is None and lighthouse.lysvidde_g is None and lighthouse.lysvidde_w is None:
            return False
        if lighthouse.height_over_sea_level is None:
            return False
        return True

    lighthouses_on_page = {
        fyrnr: lighthouse 
        for fyrnr, lighthouse in lighthouses_on_page.items() 
        if should_keep_lighthouse(lighthouse)
    }
    return lighthouses_on_page.values()

# %%
from tqdm import tqdm
pdf_path = "Fyrliste_HeleLandet.pdf"

total_number_of_lighthouses = 0
lighthouses = []
with pdfplumber.open(pdf_path) as pdf:  # type: ignore
    i = 0
    #for pdf_page in tqdm(pdf.pages, desc="Processing pages"):
    for pdf_page in pdf.pages:
        i += 1
        # if i < 700:
        #     continue
        text_on_page = pdf_page.extract_text()
        search_text = ["Lysvidde", "Fyrnr.", "Kartnr."]
        should_parse_page = all(map(lambda needle: needle in text_on_page, search_text))
        if not should_parse_page:
            continue
        print(f"Processing page {i} of {len(pdf.pages)}")
        text_elements = perform_text_extraction(pdf_page)
        # # print("text_elements: ", json.dumps(text_elements, indent=2, ensure_ascii=False))
        lighthouses_on_page = parse_lighthouses(text_elements)
        lighthouses.extend(lighthouses_on_page)
        print(f"Found {len(lighthouses)} lighthouses on page {pdf_page.page_number}")
        # for fyrnr, lighthouse in lighthouses.items():
        #     print(fyrnr, asdict(lighthouse))

print("total_number_of_lighthouses: ", total_number_of_lighthouses)
print("total_real_number_of_lighthouses: ", len(lighthouses))
# Out:
# Processing page 30 of 847
# Found 9 lighthouses on page 30
# Processing page 31 of 847
# Found 23 lighthouses on page 31
# Processing page 32 of 847
# Found 27 lighthouses on page 32
# Processing page 33 of 847
# Found 32 lighthouses on page 33
# Processing page 34 of 847
# Found 40 lighthouses on page 34
# Processing page 35 of 847
# Found 49 lighthouses on page 35
# Processing page 36 of 847
# Found 59 lighthouses on page 36
# Processing page 37 of 847
# Found 69 lighthouses on page 37
# Processing page 38 of 847
# Found 79 lighthouses on page 38
# Processing page 39 of 847
# Found 89 lighthouses on page 39
# Processing page 40 of 847
# Found 100 lighthouses on page 40
# Processing page 41 of 847
# Found 112 lighthouses on page 41
# Processing page 42 of 847
# Found 122 lighthouses on page 42
# Processing page 43 of 847
# Found 130 lighthouses on page 43
# Processing page 44 of 847
# Found 137 lighthouses on page 44
# Processing page 45 of 847
# Found 143 lighthouses on page 45
# Processing page 46 of 847
# Found 150 lighthouses on page 46
# Processing page 47 of 847
# Found 156 lighthouses on page 47
# Processing page 48 of 847
# Found 163 lighthouses on page 48
# Processing page 49 of 847
# Found 175 lighthouses on page 49
# Processing page 50 of 847
# Found 186 lighthouses on page 50
# Processing page 51 of 847
# Found 197 lighthouses on page 51
# Processing page 52 of 847
# Found 206 lighthouses on page 52
# Processing page 53 of 847
# Found 218 lighthouses on page 53
# Processing page 54 of 847
# Found 227 lighthouses on page 54
# Processing page 55 of 847
# Found 235 lighthouses on page 55
# Processing page 56 of 847
# Found 244 lighthouses on page 56
# Processing page 57 of 847
# Found 254 lighthouses on page 57
# Processing page 58 of 847
# Found 265 lighthouses on page 58
# Processing page 59 of 847
# Found 276 lighthouses on page 59
# Processing page 60 of 847
# Found 282 lighthouses on page 60
# Processing page 61 of 847
# Found 290 lighthouses on page 61
# Processing page 62 of 847
# Found 295 lighthouses on page 62
# Processing page 63 of 847
# Found 301 lighthouses on page 63
# Processing page 64 of 847
# Found 310 lighthouses on page 64
# Processing page 65 of 847
# Found 314 lighthouses on page 65
# Processing page 66 of 847
# Found 320 lighthouses on page 66
# Processing page 67 of 847
# Found 328 lighthouses on page 67
# Processing page 68 of 847
# Found 333 lighthouses on page 68
# Processing page 69 of 847
# Found 346 lighthouses on page 69
# Processing page 70 of 847
# Found 353 lighthouses on page 70
# Processing page 71 of 847
# Found 362 lighthouses on page 71
# Processing page 72 of 847
# Found 369 lighthouses on page 72
# Processing page 73 of 847
# Found 377 lighthouses on page 73
# Processing page 74 of 847
# Found 384 lighthouses on page 74
# Processing page 75 of 847
# Found 390 lighthouses on page 75
# Processing page 76 of 847
# Found 399 lighthouses on page 76
# Processing page 77 of 847
# Found 409 lighthouses on page 77
# Processing page 78 of 847
# Found 418 lighthouses on page 78
# Processing page 79 of 847
# Found 424 lighthouses on page 79
# Processing page 80 of 847
# Found 430 lighthouses on page 80
# Processing page 81 of 847
# Found 437 lighthouses on page 81
# Processing page 82 of 847
# Found 444 lighthouses on page 82
# Processing page 83 of 847
# Found 455 lighthouses on page 83
# Processing page 84 of 847
# Found 463 lighthouses on page 84
# Processing page 85 of 847
# Found 474 lighthouses on page 85
# Processing page 86 of 847
# Found 488 lighthouses on page 86
# Processing page 87 of 847
# Found 497 lighthouses on page 87
# Processing page 88 of 847
# Found 507 lighthouses on page 88
# Processing page 89 of 847
# Found 519 lighthouses on page 89
# Processing page 90 of 847
# Found 530 lighthouses on page 90
# Processing page 91 of 847
# Found 539 lighthouses on page 91
# Processing page 92 of 847
# Found 551 lighthouses on page 92
# Processing page 93 of 847
# Found 563 lighthouses on page 93
# Processing page 94 of 847
# Found 574 lighthouses on page 94
# Processing page 95 of 847
# Found 588 lighthouses on page 95
# Processing page 96 of 847
# Found 601 lighthouses on page 96
# Processing page 97 of 847
# Found 610 lighthouses on page 97
# Processing page 98 of 847
# Found 621 lighthouses on page 98
# Processing page 99 of 847
# Found 629 lighthouses on page 99
# Processing page 100 of 847
# Found 642 lighthouses on page 100
# Processing page 101 of 847
# Found 654 lighthouses on page 101
# Processing page 102 of 847
# Found 668 lighthouses on page 102
# Processing page 103 of 847
# Found 680 lighthouses on page 103
# Processing page 104 of 847
# Found 694 lighthouses on page 104
# Processing page 105 of 847
# Found 708 lighthouses on page 105
# Processing page 106 of 847
# Found 718 lighthouses on page 106
# Processing page 107 of 847
# Found 730 lighthouses on page 107
# Processing page 108 of 847
# Found 744 lighthouses on page 108
# Processing page 109 of 847
# Found 757 lighthouses on page 109
# Processing page 110 of 847
# Found 770 lighthouses on page 110
# Processing page 111 of 847
# Found 782 lighthouses on page 111
# Processing page 112 of 847
# Found 791 lighthouses on page 112
# Processing page 113 of 847
# Found 802 lighthouses on page 113
# Processing page 114 of 847
# Found 813 lighthouses on page 114
# Processing page 115 of 847
# Found 825 lighthouses on page 115
# Processing page 116 of 847
# Found 836 lighthouses on page 116
# Processing page 117 of 847
# Found 847 lighthouses on page 117
# Processing page 118 of 847
# Found 859 lighthouses on page 118
# Processing page 119 of 847
# Found 871 lighthouses on page 119
# Processing page 120 of 847
# Found 885 lighthouses on page 120
# Processing page 121 of 847
# Found 895 lighthouses on page 121
# Processing page 122 of 847
# Found 905 lighthouses on page 122
# Processing page 123 of 847
# Found 918 lighthouses on page 123
# Processing page 124 of 847
# Found 929 lighthouses on page 124
# Processing page 125 of 847
# Found 940 lighthouses on page 125
# Processing page 126 of 847
# Found 947 lighthouses on page 126
# Processing page 127 of 847
# Found 955 lighthouses on page 127
# Processing page 128 of 847
# Found 963 lighthouses on page 128
# Processing page 129 of 847
# Found 974 lighthouses on page 129
# Processing page 130 of 847
# Found 982 lighthouses on page 130
# Processing page 131 of 847
# Found 992 lighthouses on page 131
# Processing page 132 of 847
# Found 998 lighthouses on page 132
# Processing page 133 of 847
# Found 1008 lighthouses on page 133
# Processing page 134 of 847
# Found 1016 lighthouses on page 134
# Processing page 135 of 847
# Found 1022 lighthouses on page 135
# Processing page 137 of 847
# Found 1032 lighthouses on page 137
# Processing page 138 of 847
# Found 1040 lighthouses on page 138
# Processing page 139 of 847
# Found 1048 lighthouses on page 139
# Processing page 140 of 847
# Found 1058 lighthouses on page 140
# Processing page 141 of 847
# Found 1069 lighthouses on page 141
# Processing page 142 of 847
# Found 1077 lighthouses on page 142
# Processing page 143 of 847
# Found 1086 lighthouses on page 143
# Processing page 144 of 847
# Found 1093 lighthouses on page 144
# Processing page 145 of 847
# Found 1098 lighthouses on page 145
# Processing page 146 of 847
# Found 1109 lighthouses on page 146
# Processing page 147 of 847
# Found 1120 lighthouses on page 147
# Processing page 148 of 847
# Found 1126 lighthouses on page 148
# Processing page 149 of 847
# Found 1132 lighthouses on page 149
# Processing page 150 of 847
# Found 1143 lighthouses on page 150
# Processing page 151 of 847
# Found 1157 lighthouses on page 151
# Processing page 152 of 847
# Found 1166 lighthouses on page 152
# Processing page 153 of 847
# Found 1174 lighthouses on page 153
# Processing page 154 of 847
# Found 1188 lighthouses on page 154
# Processing page 155 of 847
# Found 1201 lighthouses on page 155
# Processing page 156 of 847
# Found 1211 lighthouses on page 156
# Processing page 157 of 847
# Found 1221 lighthouses on page 157
# Processing page 158 of 847
# Found 1231 lighthouses on page 158
# Processing page 159 of 847
# Found 1241 lighthouses on page 159
# Processing page 160 of 847
# Found 1253 lighthouses on page 160
# Processing page 161 of 847
# Found 1263 lighthouses on page 161
# Processing page 162 of 847
# Found 1271 lighthouses on page 162
# Processing page 163 of 847
# Found 1279 lighthouses on page 163
# Processing page 164 of 847
# Found 1289 lighthouses on page 164
# Processing page 165 of 847
# Found 1299 lighthouses on page 165
# Processing page 166 of 847
# Found 1312 lighthouses on page 166
# Processing page 167 of 847
# Found 1321 lighthouses on page 167
# Processing page 168 of 847
# Found 1328 lighthouses on page 168
# Processing page 169 of 847
# Found 1341 lighthouses on page 169
# Processing page 170 of 847
# Found 1351 lighthouses on page 170
# Processing page 171 of 847
# Found 1360 lighthouses on page 171
# Processing page 172 of 847
# Found 1362 lighthouses on page 172
# Processing page 173 of 847
# Found 1370 lighthouses on page 173
# Processing page 174 of 847
# Found 1378 lighthouses on page 174
# Processing page 175 of 847
# Found 1388 lighthouses on page 175
# Processing page 176 of 847
# Found 1402 lighthouses on page 176
# Processing page 177 of 847
# Found 1413 lighthouses on page 177
# Processing page 178 of 847
# Found 1425 lighthouses on page 178
# Processing page 179 of 847
# Found 1437 lighthouses on page 179
# Processing page 180 of 847
# Found 1446 lighthouses on page 180
# Processing page 181 of 847
# Found 1454 lighthouses on page 181
# Processing page 182 of 847
# Found 1460 lighthouses on page 182
# Processing page 183 of 847
# Found 1466 lighthouses on page 183
# Processing page 184 of 847
# Found 1476 lighthouses on page 184
# Processing page 185 of 847
# Found 1484 lighthouses on page 185
# Processing page 186 of 847
# Found 1494 lighthouses on page 186
# Processing page 187 of 847
# Found 1507 lighthouses on page 187
# Processing page 188 of 847
# Found 1512 lighthouses on page 188
# Processing page 189 of 847
# Found 1524 lighthouses on page 189
# Processing page 190 of 847
# Found 1534 lighthouses on page 190
# Processing page 191 of 847
# Found 1542 lighthouses on page 191
# Processing page 192 of 847
# Found 1547 lighthouses on page 192
# Processing page 193 of 847
# Found 1554 lighthouses on page 193
# Processing page 194 of 847
# Found 1563 lighthouses on page 194
# Processing page 195 of 847
# Found 1574 lighthouses on page 195
# Processing page 196 of 847
# Found 1580 lighthouses on page 196
# Processing page 197 of 847
# Found 1586 lighthouses on page 197
# Processing page 198 of 847
# Found 1600 lighthouses on page 198
# Processing page 199 of 847
# Found 1610 lighthouses on page 199
# Processing page 200 of 847
# Found 1620 lighthouses on page 200
# Processing page 201 of 847
# Found 1628 lighthouses on page 201
# Processing page 202 of 847
# Found 1637 lighthouses on page 202
# Processing page 203 of 847
# Found 1647 lighthouses on page 203
# Processing page 204 of 847
# Found 1654 lighthouses on page 204
# Processing page 205 of 847
# Found 1665 lighthouses on page 205
# Processing page 206 of 847
# Found 1673 lighthouses on page 206
# Processing page 207 of 847
# Found 1679 lighthouses on page 207
# Processing page 208 of 847
# Found 1686 lighthouses on page 208
# Processing page 209 of 847
# Found 1698 lighthouses on page 209
# Processing page 210 of 847
# Found 1707 lighthouses on page 210
# Processing page 211 of 847
# Found 1717 lighthouses on page 211
# Processing page 212 of 847
# Found 1724 lighthouses on page 212
# Processing page 213 of 847
# Found 1733 lighthouses on page 213
# Processing page 214 of 847
# Found 1746 lighthouses on page 214
# Processing page 215 of 847
# Found 1758 lighthouses on page 215
# Processing page 216 of 847
# Found 1767 lighthouses on page 216
# Processing page 217 of 847
# Found 1779 lighthouses on page 217
# Processing page 218 of 847
# Found 1792 lighthouses on page 218
# Processing page 219 of 847
# Found 1801 lighthouses on page 219
# Processing page 220 of 847
# Found 1813 lighthouses on page 220
# Processing page 221 of 847
# Found 1824 lighthouses on page 221
# Processing page 222 of 847
# Found 1837 lighthouses on page 222
# Processing page 223 of 847
# Found 1847 lighthouses on page 223
# Processing page 224 of 847
# Found 1854 lighthouses on page 224
# Processing page 225 of 847
# Found 1866 lighthouses on page 225
# Processing page 226 of 847
# Found 1875 lighthouses on page 226
# Processing page 227 of 847
# Found 1887 lighthouses on page 227
# Processing page 228 of 847
# Found 1891 lighthouses on page 228
# Processing page 229 of 847
# Found 1903 lighthouses on page 229
# Processing page 230 of 847
# Found 1908 lighthouses on page 230
# Processing page 231 of 847
# Found 1918 lighthouses on page 231
# Processing page 232 of 847
# Found 1926 lighthouses on page 232
# Processing page 233 of 847
# Found 1936 lighthouses on page 233
# Processing page 234 of 847
# Found 1949 lighthouses on page 234
# Processing page 235 of 847
# Found 1956 lighthouses on page 235
# Processing page 236 of 847
# Found 1962 lighthouses on page 236
# Processing page 237 of 847
# Found 1973 lighthouses on page 237
# Processing page 238 of 847
# Found 1982 lighthouses on page 238
# Processing page 239 of 847
# Found 1990 lighthouses on page 239
# Processing page 240 of 847
# Found 1995 lighthouses on page 240
# Processing page 241 of 847
# Found 1995 lighthouses on page 241
# Processing page 242 of 847
# Found 2001 lighthouses on page 242
# Processing page 243 of 847
# Found 2006 lighthouses on page 243
# Processing page 244 of 847
# Found 2016 lighthouses on page 244
# Processing page 245 of 847
# Found 2022 lighthouses on page 245
# Processing page 246 of 847
# Found 2029 lighthouses on page 246
# Processing page 247 of 847
# Found 2039 lighthouses on page 247
# Processing page 248 of 847
# Found 2051 lighthouses on page 248
# Processing page 249 of 847
# Found 2061 lighthouses on page 249
# Processing page 250 of 847
# Found 2066 lighthouses on page 250
# Processing page 251 of 847
# Found 2075 lighthouses on page 251
# Processing page 252 of 847
# Found 2085 lighthouses on page 252
# Processing page 253 of 847
# Found 2096 lighthouses on page 253
# Processing page 254 of 847
# Found 2106 lighthouses on page 254
# Processing page 255 of 847
# Found 2116 lighthouses on page 255
# Processing page 256 of 847
# Found 2128 lighthouses on page 256
# Processing page 257 of 847
# Found 2135 lighthouses on page 257
# Processing page 258 of 847
# Found 2142 lighthouses on page 258
# Processing page 259 of 847
# Found 2148 lighthouses on page 259
# Processing page 260 of 847
# Found 2153 lighthouses on page 260
# Processing page 261 of 847
# Found 2161 lighthouses on page 261
# Processing page 262 of 847
# Found 2170 lighthouses on page 262
# Processing page 263 of 847
# Found 2184 lighthouses on page 263
# Processing page 264 of 847
# Found 2193 lighthouses on page 264
# Processing page 265 of 847
# Found 2205 lighthouses on page 265
# Processing page 266 of 847
# Found 2217 lighthouses on page 266
# Processing page 267 of 847
# Found 2227 lighthouses on page 267
# Processing page 268 of 847
# Found 2234 lighthouses on page 268
# Processing page 269 of 847
# Found 2243 lighthouses on page 269
# Processing page 270 of 847
# Found 2250 lighthouses on page 270
# Processing page 271 of 847
# Found 2261 lighthouses on page 271
# Processing page 272 of 847
# Found 2270 lighthouses on page 272
# Processing page 273 of 847
# Found 2274 lighthouses on page 273
# Processing page 274 of 847
# Found 2286 lighthouses on page 274
# Processing page 275 of 847
# Found 2293 lighthouses on page 275
# Processing page 276 of 847
# Found 2305 lighthouses on page 276
# Processing page 277 of 847
# Found 2312 lighthouses on page 277
# Processing page 278 of 847
# Found 2317 lighthouses on page 278
# Processing page 279 of 847
# Found 2325 lighthouses on page 279
# Processing page 280 of 847
# Found 2339 lighthouses on page 280
# Processing page 281 of 847
# Found 2353 lighthouses on page 281
# Processing page 282 of 847
# Found 2367 lighthouses on page 282
# Processing page 283 of 847
# Found 2378 lighthouses on page 283
# Processing page 284 of 847
# Found 2391 lighthouses on page 284
# Processing page 285 of 847
# Found 2405 lighthouses on page 285
# Processing page 286 of 847
# Found 2413 lighthouses on page 286
# Processing page 287 of 847
# Found 2424 lighthouses on page 287
# Processing page 288 of 847
# Found 2432 lighthouses on page 288
# Processing page 289 of 847
# Found 2438 lighthouses on page 289
# Processing page 290 of 847
# Found 2446 lighthouses on page 290
# Processing page 291 of 847
# Found 2456 lighthouses on page 291
# Processing page 292 of 847
# Found 2465 lighthouses on page 292
# Processing page 293 of 847
# Found 2472 lighthouses on page 293
# Processing page 294 of 847
# Found 2486 lighthouses on page 294
# Processing page 295 of 847
# Found 2497 lighthouses on page 295
# Processing page 296 of 847
# Found 2511 lighthouses on page 296
# Processing page 297 of 847
# Found 2522 lighthouses on page 297
# Processing page 298 of 847
# Found 2531 lighthouses on page 298
# Processing page 299 of 847
# Found 2542 lighthouses on page 299
# Processing page 300 of 847
# Found 2554 lighthouses on page 300
# Processing page 301 of 847
# Found 2565 lighthouses on page 301
# Processing page 302 of 847
# Found 2573 lighthouses on page 302
# Processing page 303 of 847
# Found 2581 lighthouses on page 303
# Processing page 304 of 847
# Found 2593 lighthouses on page 304
# Processing page 305 of 847
# Found 2603 lighthouses on page 305
# Processing page 306 of 847
# Found 2611 lighthouses on page 306
# Processing page 307 of 847
# Found 2617 lighthouses on page 307
# Processing page 308 of 847
# Found 2623 lighthouses on page 308
# Processing page 309 of 847
# Found 2636 lighthouses on page 309
# Processing page 310 of 847
# Found 2649 lighthouses on page 310
# Processing page 311 of 847
# Found 2656 lighthouses on page 311
# Processing page 312 of 847
# Found 2667 lighthouses on page 312
# Processing page 313 of 847
# Found 2675 lighthouses on page 313
# Processing page 314 of 847
# Found 2682 lighthouses on page 314
# Processing page 315 of 847
# Found 2689 lighthouses on page 315
# Processing page 316 of 847
# Found 2696 lighthouses on page 316
# Processing page 317 of 847
# Found 2706 lighthouses on page 317
# Processing page 318 of 847
# Found 2715 lighthouses on page 318
# Processing page 319 of 847
# Found 2724 lighthouses on page 319
# Processing page 320 of 847
# Found 2735 lighthouses on page 320
# Processing page 321 of 847
# Found 2745 lighthouses on page 321
# Processing page 322 of 847
# Found 2756 lighthouses on page 322
# Processing page 323 of 847
# Found 2763 lighthouses on page 323
# Processing page 324 of 847
# Found 2773 lighthouses on page 324
# Processing page 325 of 847
# Found 2780 lighthouses on page 325
# Processing page 326 of 847
# Found 2791 lighthouses on page 326
# Processing page 327 of 847
# Found 2800 lighthouses on page 327
# Processing page 328 of 847
# Found 2814 lighthouses on page 328
# Processing page 329 of 847
# Found 2825 lighthouses on page 329
# Processing page 330 of 847
# Found 2832 lighthouses on page 330
# Processing page 331 of 847
# Found 2840 lighthouses on page 331
# Processing page 332 of 847
# Found 2848 lighthouses on page 332
# Processing page 333 of 847
# Found 2859 lighthouses on page 333
# Processing page 334 of 847
# Found 2868 lighthouses on page 334
# Processing page 335 of 847
# Found 2880 lighthouses on page 335
# Processing page 336 of 847
# Found 2891 lighthouses on page 336
# Processing page 337 of 847
# Found 2900 lighthouses on page 337
# Processing page 338 of 847
# Found 2909 lighthouses on page 338
# Processing page 339 of 847
# Found 2919 lighthouses on page 339
# Processing page 340 of 847
# Found 2926 lighthouses on page 340
# Processing page 341 of 847
# Found 2936 lighthouses on page 341
# Processing page 342 of 847
# Found 2946 lighthouses on page 342
# Processing page 343 of 847
# Found 2952 lighthouses on page 343
# Processing page 344 of 847
# Found 2965 lighthouses on page 344
# Processing page 345 of 847
# Found 2970 lighthouses on page 345
# Processing page 346 of 847
# Found 2976 lighthouses on page 346
# Processing page 348 of 847
# Found 2986 lighthouses on page 348
# Processing page 349 of 847
# Found 2996 lighthouses on page 349
# Processing page 350 of 847
# Found 3004 lighthouses on page 350
# Processing page 351 of 847
# Found 3011 lighthouses on page 351
# Processing page 352 of 847
# Found 3019 lighthouses on page 352
# Processing page 353 of 847
# Found 3029 lighthouses on page 353
# Processing page 354 of 847
# Found 3038 lighthouses on page 354
# Processing page 355 of 847
# Found 3046 lighthouses on page 355
# Processing page 356 of 847
# Found 3054 lighthouses on page 356
# Processing page 357 of 847
# Found 3057 lighthouses on page 357
# Processing page 358 of 847
# Found 3066 lighthouses on page 358
# Processing page 359 of 847
# Found 3071 lighthouses on page 359
# Processing page 360 of 847
# Found 3079 lighthouses on page 360
# Processing page 361 of 847
# Found 3087 lighthouses on page 361
# Processing page 362 of 847
# Found 3094 lighthouses on page 362
# Processing page 363 of 847
# Found 3106 lighthouses on page 363
# Processing page 364 of 847
# Found 3116 lighthouses on page 364
# Processing page 365 of 847
# Found 3121 lighthouses on page 365
# Processing page 366 of 847
# Found 3125 lighthouses on page 366
# Processing page 367 of 847
# Found 3136 lighthouses on page 367
# Processing page 368 of 847
# Found 3146 lighthouses on page 368
# Processing page 369 of 847
# Found 3150 lighthouses on page 369
# Processing page 370 of 847
# Found 3153 lighthouses on page 370
# Processing page 371 of 847
# Found 3160 lighthouses on page 371
# Processing page 372 of 847
# Found 3170 lighthouses on page 372
# Processing page 373 of 847
# Found 3182 lighthouses on page 373
# Processing page 374 of 847
# Found 3191 lighthouses on page 374
# Processing page 375 of 847
# Found 3203 lighthouses on page 375
# Processing page 376 of 847
# Found 3213 lighthouses on page 376
# Processing page 377 of 847
# Found 3221 lighthouses on page 377
# Processing page 378 of 847
# Found 3229 lighthouses on page 378
# Processing page 379 of 847
# Found 3237 lighthouses on page 379
# Processing page 380 of 847
# Found 3245 lighthouses on page 380
# Processing page 381 of 847
# Found 3253 lighthouses on page 381
# Processing page 382 of 847
# Found 3260 lighthouses on page 382
# Processing page 383 of 847
# Found 3264 lighthouses on page 383
# Processing page 384 of 847
# Found 3270 lighthouses on page 384
# Processing page 385 of 847
# Found 3274 lighthouses on page 385
# Processing page 386 of 847
# Found 3278 lighthouses on page 386
# Processing page 387 of 847
# Found 3283 lighthouses on page 387
# Processing page 388 of 847
# Found 3288 lighthouses on page 388
# Processing page 389 of 847
# Found 3295 lighthouses on page 389
# Processing page 390 of 847
# Found 3298 lighthouses on page 390
# Processing page 391 of 847
# Found 3304 lighthouses on page 391
# Processing page 392 of 847
# Found 3310 lighthouses on page 392
# Processing page 393 of 847
# Found 3317 lighthouses on page 393
# Processing page 394 of 847
# Found 3320 lighthouses on page 394
# Processing page 395 of 847
# Found 3329 lighthouses on page 395
# Processing page 396 of 847
# Found 3336 lighthouses on page 396
# Processing page 397 of 847
# Found 3343 lighthouses on page 397
# Processing page 398 of 847
# Found 3351 lighthouses on page 398
# Processing page 399 of 847
# Found 3354 lighthouses on page 399
# Processing page 400 of 847
# Found 3358 lighthouses on page 400
# Processing page 401 of 847
# Found 3366 lighthouses on page 401
# Processing page 402 of 847
# Found 3374 lighthouses on page 402
# Processing page 403 of 847
# Found 3383 lighthouses on page 403
# Processing page 404 of 847
# Found 3390 lighthouses on page 404
# Processing page 405 of 847
# Found 3398 lighthouses on page 405
# Processing page 406 of 847
# Found 3402 lighthouses on page 406
# Processing page 407 of 847
# Found 3412 lighthouses on page 407
# Processing page 408 of 847
# Found 3419 lighthouses on page 408
# Processing page 409 of 847
# Found 3424 lighthouses on page 409
# Processing page 410 of 847
# Found 3431 lighthouses on page 410
# Processing page 411 of 847
# Found 3438 lighthouses on page 411
# Processing page 412 of 847
# Found 3445 lighthouses on page 412
# Processing page 413 of 847
# Found 3448 lighthouses on page 413
# Processing page 414 of 847
# Found 3458 lighthouses on page 414
# Processing page 415 of 847
# Found 3469 lighthouses on page 415
# Processing page 416 of 847
# Found 3475 lighthouses on page 416
# Processing page 417 of 847
# Found 3484 lighthouses on page 417
# Processing page 418 of 847
# Found 3488 lighthouses on page 418
# Processing page 419 of 847
# Found 3494 lighthouses on page 419
# Processing page 420 of 847
# Found 3500 lighthouses on page 420
# Processing page 421 of 847
# Found 3505 lighthouses on page 421
# Processing page 422 of 847
# Found 3515 lighthouses on page 422
# Processing page 423 of 847
# Found 3522 lighthouses on page 423
# Processing page 424 of 847
# Found 3528 lighthouses on page 424
# Processing page 425 of 847
# Found 3534 lighthouses on page 425
# Processing page 426 of 847
# Found 3542 lighthouses on page 426
# Processing page 427 of 847
# Found 3553 lighthouses on page 427
# Processing page 428 of 847
# Found 3563 lighthouses on page 428
# Processing page 429 of 847
# Found 3572 lighthouses on page 429
# Processing page 430 of 847
# Found 3582 lighthouses on page 430
# Processing page 431 of 847
# Found 3590 lighthouses on page 431
# Processing page 432 of 847
# Found 3596 lighthouses on page 432
# Processing page 433 of 847
# Found 3606 lighthouses on page 433
# Processing page 434 of 847
# Found 3616 lighthouses on page 434
# Processing page 435 of 847
# Found 3628 lighthouses on page 435
# Processing page 436 of 847
# Found 3634 lighthouses on page 436
# Processing page 437 of 847
# Found 3638 lighthouses on page 437
# Processing page 438 of 847
# Found 3646 lighthouses on page 438
# Processing page 439 of 847
# Found 3656 lighthouses on page 439
# Processing page 440 of 847
# Found 3663 lighthouses on page 440
# Processing page 441 of 847
# Found 3671 lighthouses on page 441
# Processing page 442 of 847
# Found 3679 lighthouses on page 442
# Processing page 443 of 847
# Found 3688 lighthouses on page 443
# Processing page 444 of 847
# Found 3695 lighthouses on page 444
# Processing page 445 of 847
# Found 3704 lighthouses on page 445
# Processing page 446 of 847
# Found 3711 lighthouses on page 446
# Processing page 447 of 847
# Found 3718 lighthouses on page 447
# Processing page 448 of 847
# Found 3723 lighthouses on page 448
# Processing page 449 of 847
# Found 3728 lighthouses on page 449
# Processing page 450 of 847
# Found 3736 lighthouses on page 450
# Processing page 451 of 847
# Found 3743 lighthouses on page 451
# Processing page 452 of 847
# Found 3757 lighthouses on page 452
# Processing page 453 of 847
# Found 3770 lighthouses on page 453
# Processing page 454 of 847
# Found 3781 lighthouses on page 454
# Processing page 455 of 847
# Found 3791 lighthouses on page 455
# Processing page 456 of 847
# Found 3800 lighthouses on page 456
# Processing page 457 of 847
# Found 3811 lighthouses on page 457
# Processing page 458 of 847
# Found 3825 lighthouses on page 458
# Processing page 459 of 847
# Found 3836 lighthouses on page 459
# Processing page 460 of 847
# Found 3847 lighthouses on page 460
# Processing page 461 of 847
# Found 3854 lighthouses on page 461
# Processing page 462 of 847
# Found 3864 lighthouses on page 462
# Processing page 463 of 847
# Found 3874 lighthouses on page 463
# Processing page 464 of 847
# Found 3880 lighthouses on page 464
# Processing page 465 of 847
# Found 3889 lighthouses on page 465
# Processing page 466 of 847
# Found 3898 lighthouses on page 466
# Processing page 467 of 847
# Found 3908 lighthouses on page 467
# Processing page 468 of 847
# Found 3918 lighthouses on page 468
# Processing page 469 of 847
# Found 3925 lighthouses on page 469
# Processing page 470 of 847
# Found 3931 lighthouses on page 470
# Processing page 471 of 847
# Found 3940 lighthouses on page 471
# Processing page 472 of 847
# Found 3947 lighthouses on page 472
# Processing page 473 of 847
# Found 3960 lighthouses on page 473
# Processing page 474 of 847
# Found 3971 lighthouses on page 474
# Processing page 475 of 847
# Found 3983 lighthouses on page 475
# Processing page 476 of 847
# Found 3991 lighthouses on page 476
# Processing page 477 of 847
# Found 4001 lighthouses on page 477
# Processing page 478 of 847
# Found 4015 lighthouses on page 478
# Processing page 479 of 847
# Found 4024 lighthouses on page 479
# Processing page 480 of 847
# Found 4033 lighthouses on page 480
# Processing page 481 of 847
# Found 4041 lighthouses on page 481
# Processing page 482 of 847
# Found 4053 lighthouses on page 482
# Processing page 483 of 847
# Found 4060 lighthouses on page 483
# Processing page 484 of 847
# Found 4067 lighthouses on page 484
# Processing page 485 of 847
# Found 4071 lighthouses on page 485
# Processing page 486 of 847
# Found 4075 lighthouses on page 486
# Processing page 487 of 847
# Found 4080 lighthouses on page 487
# Processing page 488 of 847
# Found 4088 lighthouses on page 488
# Processing page 489 of 847
# Found 4094 lighthouses on page 489
# Processing page 490 of 847
# Found 4101 lighthouses on page 490
# Processing page 491 of 847
# Found 4107 lighthouses on page 491
# Processing page 492 of 847
# Found 4113 lighthouses on page 492
# Processing page 493 of 847
# Found 4120 lighthouses on page 493
# Processing page 494 of 847
# Found 4127 lighthouses on page 494
# Processing page 495 of 847
# Found 4133 lighthouses on page 495
# Processing page 496 of 847
# Found 4136 lighthouses on page 496
# Processing page 497 of 847
# Found 4143 lighthouses on page 497
# Processing page 498 of 847
# Found 4154 lighthouses on page 498
# Processing page 499 of 847
# Found 4162 lighthouses on page 499
# Processing page 500 of 847
# Found 4171 lighthouses on page 500
# Processing page 501 of 847
# Found 4178 lighthouses on page 501
# Processing page 502 of 847
# Found 4185 lighthouses on page 502
# Processing page 503 of 847
# Found 4195 lighthouses on page 503
# Processing page 504 of 847
# Found 4209 lighthouses on page 504
# Processing page 505 of 847
# Found 4220 lighthouses on page 505
# Processing page 506 of 847
# Found 4227 lighthouses on page 506
# Processing page 507 of 847
# Found 4232 lighthouses on page 507
# Processing page 508 of 847
# Found 4238 lighthouses on page 508
# Processing page 509 of 847
# Found 4247 lighthouses on page 509
# Processing page 510 of 847
# Found 4253 lighthouses on page 510
# Processing page 511 of 847
# Found 4262 lighthouses on page 511
# Processing page 512 of 847
# Found 4272 lighthouses on page 512
# Processing page 513 of 847
# Found 4282 lighthouses on page 513
# Processing page 514 of 847
# Found 4288 lighthouses on page 514
# Processing page 515 of 847
# Found 4299 lighthouses on page 515
# Processing page 516 of 847
# Found 4307 lighthouses on page 516
# Processing page 517 of 847
# Found 4314 lighthouses on page 517
# Processing page 518 of 847
# Found 4321 lighthouses on page 518
# Processing page 519 of 847
# Found 4328 lighthouses on page 519
# Processing page 520 of 847
# Found 4339 lighthouses on page 520
# Processing page 521 of 847
# Found 4347 lighthouses on page 521
# Processing page 522 of 847
# Found 4351 lighthouses on page 522
# Processing page 523 of 847
# Found 4361 lighthouses on page 523
# Processing page 524 of 847
# Found 4371 lighthouses on page 524
# Processing page 525 of 847
# Found 4381 lighthouses on page 525
# Processing page 526 of 847
# Found 4389 lighthouses on page 526
# Processing page 527 of 847
# Found 4396 lighthouses on page 527
# Processing page 528 of 847
# Found 4404 lighthouses on page 528
# Processing page 529 of 847
# Found 4413 lighthouses on page 529
# Processing page 530 of 847
# Found 4418 lighthouses on page 530
# Processing page 531 of 847
# Found 4422 lighthouses on page 531
# Processing page 532 of 847
# Found 4426 lighthouses on page 532
# Processing page 533 of 847
# Found 4435 lighthouses on page 533
# Processing page 534 of 847
# Found 4444 lighthouses on page 534
# Processing page 535 of 847
# Found 4450 lighthouses on page 535
# Processing page 536 of 847
# Found 4459 lighthouses on page 536
# Processing page 537 of 847
# Found 4464 lighthouses on page 537
# Processing page 539 of 847
# Found 4468 lighthouses on page 539
# Processing page 540 of 847
# Found 4477 lighthouses on page 540
# Processing page 541 of 847
# Found 4484 lighthouses on page 541
# Processing page 542 of 847
# Found 4495 lighthouses on page 542
# Processing page 543 of 847
# Found 4504 lighthouses on page 543
# Processing page 544 of 847
# Found 4510 lighthouses on page 544
# Processing page 545 of 847
# Found 4517 lighthouses on page 545
# Processing page 546 of 847
# Found 4524 lighthouses on page 546
# Processing page 547 of 847
# Found 4528 lighthouses on page 547
# Processing page 548 of 847
# Found 4537 lighthouses on page 548
# Processing page 549 of 847
# Found 4546 lighthouses on page 549
# Processing page 550 of 847
# Found 4555 lighthouses on page 550
# Processing page 551 of 847
# Found 4563 lighthouses on page 551
# Processing page 552 of 847
# Found 4567 lighthouses on page 552
# Processing page 553 of 847
# Found 4572 lighthouses on page 553
# Processing page 554 of 847
# Found 4578 lighthouses on page 554
# Processing page 555 of 847
# Found 4583 lighthouses on page 555
# Processing page 556 of 847
# Found 4595 lighthouses on page 556
# Processing page 557 of 847
# Found 4599 lighthouses on page 557
# Processing page 558 of 847
# Found 4610 lighthouses on page 558
# Processing page 559 of 847
# Found 4621 lighthouses on page 559
# Processing page 560 of 847
# Found 4626 lighthouses on page 560
# Processing page 561 of 847
# Found 4636 lighthouses on page 561
# Processing page 562 of 847
# Found 4644 lighthouses on page 562
# Processing page 563 of 847
# Found 4652 lighthouses on page 563
# Processing page 564 of 847
# Found 4659 lighthouses on page 564
# Processing page 565 of 847
# Found 4671 lighthouses on page 565
# Processing page 566 of 847
# Found 4683 lighthouses on page 566
# Processing page 567 of 847
# Found 4691 lighthouses on page 567
# Processing page 568 of 847
# Found 4699 lighthouses on page 568
# Processing page 569 of 847
# Found 4707 lighthouses on page 569
# Processing page 570 of 847
# Found 4715 lighthouses on page 570
# Processing page 571 of 847
# Found 4726 lighthouses on page 571
# Processing page 572 of 847
# Found 4734 lighthouses on page 572
# Processing page 573 of 847
# Found 4742 lighthouses on page 573
# Processing page 574 of 847
# Found 4750 lighthouses on page 574
# Processing page 575 of 847
# Found 4764 lighthouses on page 575
# Processing page 576 of 847
# Found 4773 lighthouses on page 576
# Processing page 577 of 847
# Found 4784 lighthouses on page 577
# Processing page 578 of 847
# Found 4796 lighthouses on page 578
# Processing page 579 of 847
# Found 4807 lighthouses on page 579
# Processing page 580 of 847
# Found 4815 lighthouses on page 580
# Processing page 581 of 847
# Found 4827 lighthouses on page 581
# Processing page 582 of 847
# Found 4839 lighthouses on page 582
# Processing page 583 of 847
# Found 4847 lighthouses on page 583
# Processing page 584 of 847
# Found 4860 lighthouses on page 584
# Processing page 585 of 847
# Found 4871 lighthouses on page 585
# Processing page 586 of 847
# Found 4878 lighthouses on page 586
# Processing page 587 of 847
# Found 4889 lighthouses on page 587
# Processing page 588 of 847
# Found 4900 lighthouses on page 588
# Processing page 589 of 847
# Found 4913 lighthouses on page 589
# Processing page 590 of 847
# Found 4923 lighthouses on page 590
# Processing page 591 of 847
# Found 4930 lighthouses on page 591
# Processing page 592 of 847
# Found 4940 lighthouses on page 592
# Processing page 593 of 847
# Found 4948 lighthouses on page 593
# Processing page 594 of 847
# Found 4961 lighthouses on page 594
# Processing page 595 of 847
# Found 4973 lighthouses on page 595
# Processing page 596 of 847
# Found 4983 lighthouses on page 596
# Processing page 597 of 847
# Found 4995 lighthouses on page 597
# Processing page 598 of 847
# Found 5001 lighthouses on page 598
# Processing page 599 of 847
# Found 5006 lighthouses on page 599
# Processing page 600 of 847
# Found 5009 lighthouses on page 600
# Processing page 601 of 847
# Found 5015 lighthouses on page 601
# Processing page 602 of 847
# Found 5026 lighthouses on page 602
# Processing page 603 of 847
# Found 5040 lighthouses on page 603
# Processing page 604 of 847
# Found 5047 lighthouses on page 604
# Processing page 605 of 847
# Found 5057 lighthouses on page 605
# Processing page 606 of 847
# Found 5064 lighthouses on page 606
# Processing page 607 of 847
# Found 5069 lighthouses on page 607
# Processing page 608 of 847
# Found 5081 lighthouses on page 608
# Processing page 609 of 847
# Found 5095 lighthouses on page 609
# Processing page 610 of 847
# Found 5104 lighthouses on page 610
# Processing page 611 of 847
# Found 5109 lighthouses on page 611
# Processing page 612 of 847
# Found 5117 lighthouses on page 612
# Processing page 613 of 847
# Found 5124 lighthouses on page 613
# Processing page 614 of 847
# Found 5131 lighthouses on page 614
# Processing page 615 of 847
# Found 5139 lighthouses on page 615
# Processing page 616 of 847
# Found 5147 lighthouses on page 616
# Processing page 617 of 847
# Found 5157 lighthouses on page 617
# Processing page 618 of 847
# Found 5164 lighthouses on page 618
# Processing page 619 of 847
# Found 5177 lighthouses on page 619
# Processing page 620 of 847
# Found 5189 lighthouses on page 620
# Processing page 621 of 847
# Found 5199 lighthouses on page 621
# Processing page 622 of 847
# Found 5208 lighthouses on page 622
# Processing page 623 of 847
# Found 5218 lighthouses on page 623
# Processing page 624 of 847
# Found 5221 lighthouses on page 624
# Processing page 625 of 847
# Found 5229 lighthouses on page 625
# Processing page 626 of 847
# Found 5238 lighthouses on page 626
# Processing page 627 of 847
# Found 5248 lighthouses on page 627
# Processing page 628 of 847
# Found 5257 lighthouses on page 628
# Processing page 629 of 847
# Found 5260 lighthouses on page 629
# Processing page 630 of 847
# Found 5267 lighthouses on page 630
# Processing page 631 of 847
# Found 5273 lighthouses on page 631
# Processing page 632 of 847
# Found 5282 lighthouses on page 632
# Processing page 633 of 847
# Found 5294 lighthouses on page 633
# Processing page 634 of 847
# Found 5304 lighthouses on page 634
# Processing page 635 of 847
# Found 5314 lighthouses on page 635
# Processing page 636 of 847
# Found 5322 lighthouses on page 636
# Processing page 637 of 847
# Found 5330 lighthouses on page 637
# Processing page 638 of 847
# Found 5337 lighthouses on page 638
# Processing page 639 of 847
# Found 5344 lighthouses on page 639
# Processing page 640 of 847
# Found 5354 lighthouses on page 640
# Processing page 641 of 847
# Found 5361 lighthouses on page 641
# Processing page 642 of 847
# Found 5368 lighthouses on page 642
# Processing page 643 of 847
# Found 5379 lighthouses on page 643
# Processing page 644 of 847
# Found 5389 lighthouses on page 644
# Processing page 645 of 847
# Found 5398 lighthouses on page 645
# Processing page 646 of 847
# Found 5407 lighthouses on page 646
# Processing page 647 of 847
# Found 5413 lighthouses on page 647
# Processing page 648 of 847
# Found 5419 lighthouses on page 648
# Processing page 649 of 847
# Found 5426 lighthouses on page 649
# Processing page 650 of 847
# Found 5432 lighthouses on page 650
# Processing page 651 of 847
# Found 5439 lighthouses on page 651
# Processing page 652 of 847
# Found 5445 lighthouses on page 652
# Processing page 653 of 847
# Found 5458 lighthouses on page 653
# Processing page 654 of 847
# Found 5471 lighthouses on page 654
# Processing page 655 of 847
# Found 5481 lighthouses on page 655
# Processing page 656 of 847
# Found 5488 lighthouses on page 656
# Processing page 657 of 847
# Found 5495 lighthouses on page 657
# Processing page 658 of 847
# Found 5503 lighthouses on page 658
# Processing page 659 of 847
# Found 5513 lighthouses on page 659
# Processing page 660 of 847
# Found 5520 lighthouses on page 660
# Processing page 661 of 847
# Found 5530 lighthouses on page 661
# Processing page 662 of 847
# Found 5538 lighthouses on page 662
# Processing page 663 of 847
# Found 5546 lighthouses on page 663
# Processing page 664 of 847
# Found 5554 lighthouses on page 664
# Processing page 665 of 847
# Found 5564 lighthouses on page 665
# Processing page 666 of 847
# Found 5573 lighthouses on page 666
# Processing page 667 of 847
# Found 5581 lighthouses on page 667
# Processing page 668 of 847
# Found 5588 lighthouses on page 668
# Processing page 669 of 847
# Found 5597 lighthouses on page 669
# Processing page 670 of 847
# Found 5608 lighthouses on page 670
# Processing page 671 of 847
# Found 5621 lighthouses on page 671
# Processing page 672 of 847
# Found 5630 lighthouses on page 672
# Processing page 673 of 847
# Found 5642 lighthouses on page 673
# Processing page 674 of 847
# Found 5652 lighthouses on page 674
# Processing page 675 of 847
# Found 5659 lighthouses on page 675
# Processing page 676 of 847
# Found 5670 lighthouses on page 676
# Processing page 677 of 847
# Found 5676 lighthouses on page 677
# Processing page 678 of 847
# Found 5682 lighthouses on page 678
# Processing page 679 of 847
# Found 5687 lighthouses on page 679
# Processing page 680 of 847
# Found 5693 lighthouses on page 680
# Processing page 681 of 847
# Found 5702 lighthouses on page 681
# Processing page 682 of 847
# Found 5708 lighthouses on page 682
# Processing page 683 of 847
# Found 5712 lighthouses on page 683
# Processing page 684 of 847
# Found 5720 lighthouses on page 684
# Processing page 685 of 847
# Found 5732 lighthouses on page 685
# Processing page 686 of 847
# Found 5737 lighthouses on page 686
# Processing page 687 of 847
# Found 5745 lighthouses on page 687
# Processing page 688 of 847
# Found 5754 lighthouses on page 688
# Processing page 689 of 847
# Found 5763 lighthouses on page 689
# Processing page 690 of 847
# Found 5772 lighthouses on page 690
# Processing page 691 of 847
# Found 5779 lighthouses on page 691
# Processing page 692 of 847
# Found 5788 lighthouses on page 692
# Processing page 693 of 847
# Found 5794 lighthouses on page 693
# Processing page 694 of 847
# Found 5802 lighthouses on page 694
# Processing page 695 of 847
# Found 5809 lighthouses on page 695
# Processing page 696 of 847
# Found 5818 lighthouses on page 696
# Processing page 697 of 847
# Found 5823 lighthouses on page 697
# Processing page 698 of 847
# Found 5832 lighthouses on page 698
# Processing page 699 of 847
# Found 5842 lighthouses on page 699
# Processing page 700 of 847
# Found 5850 lighthouses on page 700
# Processing page 701 of 847
# Found 5857 lighthouses on page 701
# Processing page 702 of 847
# WARNING! Sector from is None for 774506 R None. Choosing 0.0 instead.
# Found 5866 lighthouses on page 702
# Processing page 703 of 847
# Found 5875 lighthouses on page 703
# Processing page 704 of 847
# Found 5879 lighthouses on page 704
# Processing page 705 of 847
# Found 5884 lighthouses on page 705
# Processing page 706 of 847
# Found 5889 lighthouses on page 706
# Processing page 707 of 847
# Found 5899 lighthouses on page 707
# Processing page 708 of 847
# Found 5909 lighthouses on page 708
# Processing page 709 of 847
# Found 5914 lighthouses on page 709
# Processing page 710 of 847
# Found 5923 lighthouses on page 710
# Processing page 711 of 847
# Found 5926 lighthouses on page 711
# Processing page 712 of 847
# Found 5930 lighthouses on page 712
# Processing page 713 of 847
# Found 5936 lighthouses on page 713
# Processing page 714 of 847
# Found 5943 lighthouses on page 714
# Processing page 715 of 847
# Found 5948 lighthouses on page 715
# Processing page 716 of 847
# Found 5955 lighthouses on page 716
# Processing page 717 of 847
# Found 5960 lighthouses on page 717
# Processing page 718 of 847
# Found 5969 lighthouses on page 718
# Processing page 719 of 847
# Found 5977 lighthouses on page 719
# Processing page 720 of 847
# Found 5986 lighthouses on page 720
# Processing page 721 of 847
# Found 5995 lighthouses on page 721
# Processing page 722 of 847
# Found 6001 lighthouses on page 722
# Processing page 723 of 847
# Found 6007 lighthouses on page 723
# Processing page 724 of 847
# Found 6015 lighthouses on page 724
# Processing page 725 of 847
# Found 6022 lighthouses on page 725
# Processing page 726 of 847
# Found 6025 lighthouses on page 726
# Processing page 727 of 847
# Found 6031 lighthouses on page 727
# Processing page 728 of 847
# Found 6041 lighthouses on page 728
# Processing page 729 of 847
# Found 6048 lighthouses on page 729
# Processing page 730 of 847
# Found 6053 lighthouses on page 730
# Processing page 731 of 847
# Found 6063 lighthouses on page 731
# Processing page 732 of 847
# Found 6070 lighthouses on page 732
# Processing page 733 of 847
# Found 6076 lighthouses on page 733
# Processing page 734 of 847
# Found 6087 lighthouses on page 734
# Processing page 735 of 847
# Found 6100 lighthouses on page 735
# Processing page 736 of 847
# Found 6109 lighthouses on page 736
# Processing page 737 of 847
# Found 6117 lighthouses on page 737
# Processing page 738 of 847
# Found 6127 lighthouses on page 738
# Processing page 739 of 847
# Found 6138 lighthouses on page 739
# Processing page 740 of 847
# Found 6145 lighthouses on page 740
# Processing page 741 of 847
# Found 6155 lighthouses on page 741
# Processing page 742 of 847
# Found 6164 lighthouses on page 742
# Processing page 743 of 847
# Found 6174 lighthouses on page 743
# Processing page 744 of 847
# Found 6177 lighthouses on page 744
# Processing page 745 of 847
# Found 6185 lighthouses on page 745
# Processing page 746 of 847
# Found 6196 lighthouses on page 746
# Processing page 747 of 847
# Found 6203 lighthouses on page 747
# Processing page 748 of 847
# Found 6212 lighthouses on page 748
# Processing page 749 of 847
# Found 6218 lighthouses on page 749
# Processing page 750 of 847
# Found 6223 lighthouses on page 750
# Processing page 752 of 847
# Found 6229 lighthouses on page 752
# Processing page 753 of 847
# Found 6238 lighthouses on page 753
# Processing page 754 of 847
# Found 6247 lighthouses on page 754
# Processing page 755 of 847
# Found 6252 lighthouses on page 755
# Processing page 756 of 847
# Found 6262 lighthouses on page 756
# Processing page 757 of 847
# Found 6272 lighthouses on page 757
# Processing page 758 of 847
# Found 6280 lighthouses on page 758
# Processing page 759 of 847
# Found 6287 lighthouses on page 759
# Processing page 760 of 847
# Found 6295 lighthouses on page 760
# Processing page 761 of 847
# Found 6304 lighthouses on page 761
# Processing page 762 of 847
# Found 6308 lighthouses on page 762
# Processing page 763 of 847
# Found 6313 lighthouses on page 763
# Processing page 764 of 847
# Found 6319 lighthouses on page 764
# Processing page 765 of 847
# Found 6329 lighthouses on page 765
# Processing page 766 of 847
# Found 6334 lighthouses on page 766
# Processing page 767 of 847
# Found 6341 lighthouses on page 767
# Processing page 768 of 847
# Found 6350 lighthouses on page 768
# Processing page 769 of 847
# Found 6358 lighthouses on page 769
# Processing page 770 of 847
# Found 6368 lighthouses on page 770
# Processing page 771 of 847
# Found 6378 lighthouses on page 771
# Processing page 772 of 847
# Found 6382 lighthouses on page 772
# Processing page 773 of 847
# Found 6386 lighthouses on page 773
# Processing page 774 of 847
# Found 6390 lighthouses on page 774
# Processing page 775 of 847
# Found 6396 lighthouses on page 775
# Processing page 776 of 847
# Found 6400 lighthouses on page 776
# Processing page 777 of 847
# Found 6406 lighthouses on page 777
# Processing page 778 of 847
# Found 6412 lighthouses on page 778
# Processing page 779 of 847
# Found 6421 lighthouses on page 779
# Processing page 780 of 847
# Found 6428 lighthouses on page 780
# Processing page 781 of 847
# Found 6438 lighthouses on page 781
# Processing page 782 of 847
# Found 6444 lighthouses on page 782
# Processing page 783 of 847
# Found 6454 lighthouses on page 783
# Processing page 784 of 847
# Found 6463 lighthouses on page 784
# Processing page 785 of 847
# Found 6474 lighthouses on page 785
# Processing page 786 of 847
# Found 6480 lighthouses on page 786
# Processing page 787 of 847
# Found 6486 lighthouses on page 787
# Processing page 788 of 847
# Found 6491 lighthouses on page 788
# Processing page 789 of 847
# Found 6499 lighthouses on page 789
# Processing page 790 of 847
# Found 6508 lighthouses on page 790
# Processing page 791 of 847
# Found 6517 lighthouses on page 791
# Processing page 792 of 847
# Found 6528 lighthouses on page 792
# Processing page 793 of 847
# Found 6536 lighthouses on page 793
# Processing page 794 of 847
# Found 6544 lighthouses on page 794
# Processing page 795 of 847
# Found 6550 lighthouses on page 795
# Processing page 796 of 847
# Found 6556 lighthouses on page 796
# Processing page 797 of 847
# Found 6565 lighthouses on page 797
# Processing page 798 of 847
# Found 6573 lighthouses on page 798
# Processing page 799 of 847
# Found 6582 lighthouses on page 799
# Processing page 800 of 847
# Found 6592 lighthouses on page 800
# Processing page 801 of 847
# Found 6600 lighthouses on page 801
# Processing page 802 of 847
# Found 6607 lighthouses on page 802
# Processing page 803 of 847
# Found 6616 lighthouses on page 803
# Processing page 804 of 847
# Found 6623 lighthouses on page 804
# Processing page 805 of 847
# Found 6632 lighthouses on page 805
# Processing page 806 of 847
# Found 6639 lighthouses on page 806
# Processing page 807 of 847
# Found 6646 lighthouses on page 807
# Processing page 808 of 847
# Found 6654 lighthouses on page 808
# Processing page 809 of 847
# Found 6663 lighthouses on page 809
# Processing page 810 of 847
# Found 6674 lighthouses on page 810
# Processing page 811 of 847
# Found 6685 lighthouses on page 811
# Processing page 812 of 847
# Found 6695 lighthouses on page 812
# Processing page 813 of 847
# Found 6705 lighthouses on page 813
# Processing page 814 of 847
# Found 6712 lighthouses on page 814
# Processing page 815 of 847
# Found 6721 lighthouses on page 815
# Processing page 816 of 847
# Found 6729 lighthouses on page 816
# Processing page 817 of 847
# Found 6734 lighthouses on page 817
# Processing page 818 of 847
# Found 6742 lighthouses on page 818
# Processing page 819 of 847
# Found 6750 lighthouses on page 819
# Processing page 820 of 847
# Found 6759 lighthouses on page 820
# Processing page 821 of 847
# Found 6767 lighthouses on page 821
# Processing page 822 of 847
# Found 6780 lighthouses on page 822
# Processing page 823 of 847
# Found 6786 lighthouses on page 823
# Processing page 824 of 847
# Found 6792 lighthouses on page 824
# Processing page 825 of 847
# Found 6802 lighthouses on page 825
# Processing page 826 of 847
# Found 6810 lighthouses on page 826
# Processing page 827 of 847
# Found 6815 lighthouses on page 827
# Processing page 828 of 847
# Found 6824 lighthouses on page 828
# Processing page 829 of 847
# Found 6832 lighthouses on page 829
# Processing page 830 of 847
# Found 6844 lighthouses on page 830
# Processing page 831 of 847
# Found 6853 lighthouses on page 831
# Processing page 832 of 847
# Found 6859 lighthouses on page 832
# Processing page 833 of 847
# Found 6869 lighthouses on page 833
# Processing page 834 of 847
# Found 6879 lighthouses on page 834
# Processing page 835 of 847
# Found 6887 lighthouses on page 835
# Processing page 836 of 847
# Found 6897 lighthouses on page 836
# Processing page 837 of 847
# Found 6905 lighthouses on page 837
# Processing page 838 of 847
# Found 6913 lighthouses on page 838
# Processing page 839 of 847
# Found 6920 lighthouses on page 839
# Processing page 840 of 847
# Found 6926 lighthouses on page 840
# Processing page 841 of 847
# Found 6930 lighthouses on page 841
# Processing page 843 of 847
# Found 6933 lighthouses on page 843
# Processing page 844 of 847
# Found 6941 lighthouses on page 844
# Processing page 845 of 847
# Found 6949 lighthouses on page 845
# Processing page 846 of 847
# Found 6954 lighthouses on page 846
# Processing page 847 of 847
# Found 6956 lighthouses on page 847
# total_number_of_lighthouses:  7864
# total_real_number_of_lighthouses:  6956
